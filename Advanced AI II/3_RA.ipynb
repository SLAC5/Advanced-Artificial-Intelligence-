# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_regression

# %%
# Generate a synthetic dataset
X, y = make_regression(n_samples=200, n_features=1, noise=20, random_state=42)

# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Fit regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict the values using the test set
y_pred = model.predict(X_test)

# %%
# Residuals
residuals = y_test - y_pred

# Plot the residuals
plt.scatter(X_test, residuals)
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel('X_test')
plt.ylabel('Residuals')
# Out:
# Text(0, 0.5, 'Residuals')

# %%
# Plotting data and regression
plt.figure(figsize=(5,5))
sns.scatterplot(x=X_test.flatten(), y=y_test, label='current', color='blue')
sns.scatterplot(x=X_test.flatten(), y=y_pred, label='predicted', color='red')
plt.legend()
plt.xlabel('X_test: Independent Variables')
plt.ylabel('y_tes: Dependent Variable')
plt.title('Regression Plot')
plt.show()

# %%
# Plot: Homoscedasticity
plt.figure(figsize=(5,5))
sns.scatterplot(x=y_pred, y=np.abs(residuals))
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel('Predicted Values')
plt.ylabel('Absolute Residuals')
plt.title('Homoscedasticity Plot')
plt.show()

# %%
# Generate dataset
np.random.seed(42)
X_example = np.random.rand(200, 1) * 100
y_example = 2 * X_example.squeeze() + np.random.normal(0, X_example.squeeze(), 200)

# Split in test and train
X_train, X_test, y_train, y_test = train_test_split(X_example, y_example, test_size=0.3, random_state=42)

# Train a model
model_h = LinearRegression()
model_h.fit(X_train, y_train)
y_pred_h = model_h.predict(X_test)

# %%
# Plot residuals
residuals_h = y_test - y_pred_h
plt.figure(figsize=(5,5))
sns.scatterplot(x=y_pred_h, y=residuals_h)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=y_pred_h, y=np.abs(residuals_h))
plt.xlabel('Predicted Values')
plt.ylabel('Absolute Residuals')
plt.title('Homoscedasticity Plot')
plt.show()

# %%
# Plot normality of residuals
plt.figure(figsize=(5,5))
sns.histplot(residuals, kde=True)
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.title('Histogram of Residuals')
plt.show()

# %%
# Plot normality of residuals
plt.figure(figsize=(5,5))
sns.histplot(residuals_h, kde=True)
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.title('Histogram of Residuals')
plt.show()

# %%
# Plot Q-Q plot
plt.figure(figsize=(5,5))
sm.qqplot(residuals, line='s')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')
plt.title('Q-Q Plot')
plt.show()

# %% [markdown]
# # **Wine dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Semestres/S7/IA II/M1_Stats for Data Science II/W2/WineQT.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %%
X = df.drop(['quality'], axis=1)
y = df['quality']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Fit regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict the values using the test set
y_pred = model.predict(X_test)

# %%
# Residuals
residuals = y_test - y_pred

# Plot the residuals
for col in X_test.columns:
  plt.figure(figsize=(5,5))
  plt.scatter(X_test[col], residuals)
  plt.axhline(y=0, color='r', linestyle='--')
  plt.xlabel('X_test')
  plt.ylabel('Residuals')
  plt.title(f'Residuals vs {col}')
  plt.show()
  print()

# %%
# Plotting data and regression
for col in X_test.columns:
  plt.figure(figsize=(5,5))
  sns.scatterplot(x=X_test[col], y=y_test, label='current', color='blue')
  sns.scatterplot(x=X_test[col], y=y_pred, label='predicted', color='red')
  plt.legend()
  plt.xlabel(f'X_test: {col}')
  plt.ylabel('y_test: quality')
  plt.title('Regression Plot')
  plt.show()
  print()

# %%
# Plot: Homoscedasticity
plt.figure(figsize=(5,5))
sns.scatterplot(x=y_pred, y=np.abs(residuals))
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel('Predicted Values')
plt.ylabel('Absolute Residuals')
plt.title('Homoscedasticity Plot')
plt.show()

# %%
# Plot normality of residuals
plt.figure(figsize=(5,5))
sns.histplot(residuals, kde=True)
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.title('Histogram of Residuals')
plt.show()
