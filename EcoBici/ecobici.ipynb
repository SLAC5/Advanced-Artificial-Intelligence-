# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import io

print("Librerias importadas correctamente")

# ==============================================================================================
# Out:
# Librerias importadas correctamente

# %%
# leer el csv
csv_fle = pd.read_csv('./2025-04.csv')

# Mostrar el tamaño del df (filas y columnas)
print("Tamaño del df:")
display(csv_fle.shape)

# Mostrar una previsualizacion de los datos
print("Previsualizacion del df:\n")
display(csv_fle.head(50))
# Out:
# Tamaño del df:
# (1727987, 9)
# Previsualizacion del df:
#    Genero_Usuario  Edad_Usuario     Bici Ciclo_Estacion_Retiro Fecha_Retiro  \
# 0               F          22.0  2586485               107-108   31/03/2025
# 1               M          50.0  8152522                   384   31/03/2025
# 2               M          24.0  4219945                   021   31/03/2025
# 3               M          32.0  2286540               271-272   31/03/2025
# 4               M          26.0  5017868                   538   31/03/2025
# 5               M          22.0  5918198                   260   31/03/2025
# 6               M          32.0  7051410                   702   31/03/2025
# 7               M          28.0  4163572                   116   31/03/2025
# 8               M          27.0  8924565                   175   31/03/2025
# 9               M          29.0  5694922                   030   31/03/2025
# 10              M          46.0  8725350                   308   31/03/2025
# ...

# %%
# Regresar valores únicos
print(csv_fle["Genero_Usuario"].unique())
# Out:
# ['F' 'M' '?' 'O' nan]

# %%
# Contamos cantidad de registros para cada genero
print(csv_fle["Genero_Usuario"].value_counts(dropna=False))
# Out:
# Genero_Usuario
# M      1177624
# F       484899
# O        32835
# ?        32628
# NaN          1
# Name: count, dtype: int64

# %%
# Agregamos todos los valores diferentes de "M" y "F" a "O" (other)
csv_fle["Genero_Usuario"] = csv_fle["Genero_Usuario"].where(csv_fle["Genero_Usuario"].isin(["M", "F"]), "O")
print(csv_fle["Genero_Usuario"].value_counts())
# Out:
# Genero_Usuario
# M    1177624
# F     484899
# O      65464
# Name: count, dtype: int64

# %%
# AHora vamos a cambiar los valores de edades de elementos flotantes a enteros (no necesitamos flotantes porque son edades)
csv_fle["Edad_Usuario"] = csv_fle["Edad_Usuario"].astype("Int64")
display(csv_fle.head(20))
# Out:
#    Genero_Usuario  Edad_Usuario     Bici Ciclo_Estacion_Retiro Fecha_Retiro  \
# 0               F            22  2586485               107-108   31/03/2025
# 1               M            50  8152522                   384   31/03/2025
# 2               M            24  4219945                   021   31/03/2025
# 3               M            32  2286540               271-272   31/03/2025
# 4               M            26  5017868                   538   31/03/2025
# 5               M            22  5918198                   260   31/03/2025
# 6               M            32  7051410                   702   31/03/2025
# 7               M            28  4163572                   116   31/03/2025
# 8               M            27  8924565                   175   31/03/2025
# 9               M            29  5694922                   030   31/03/2025
# 10              M            46  8725350                   308   31/03/2025
# ...

# %%
# Cambiar el nombre de la columna "Bici" a "Bici_UUID"
csv_fle.rename(columns={"Bici": "Bici_UUID"}, inplace=True)
display(csv_fle.head(20))
# Out:
#    Genero_Usuario  Edad_Usuario  Bici_UUID Ciclo_Estacion_Retiro Fecha_Retiro  \
# 0               F            22    2586485               107-108   31/03/2025
# 1               M            50    8152522                   384   31/03/2025
# 2               M            24    4219945                   021   31/03/2025
# 3               M            32    2286540               271-272   31/03/2025
# 4               M            26    5017868                   538   31/03/2025
# 5               M            22    5918198                   260   31/03/2025
# 6               M            32    7051410                   702   31/03/2025
# 7               M            28    4163572                   116   31/03/2025
# 8               M            27    8924565                   175   31/03/2025
# 9               M            29    5694922                   030   31/03/2025
# 10              M            46    8725350                   308   31/03/2025
# ...
